# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib

import sys
sys.path.append('/../../temp_prog/')
import vb_epsilon_sweeper as vs
import file_handler as fh
# Out:
# WARNING: Cannot import Cython compiled modules for the special functions (specfunc.__init__.py).
# WARNING: Cannot import Cython compiled modules for the approaches (builder_base.py).
# WARNING: Cannot import Cython compiled modules for the approaches (builder_elph.py).

# %%
#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-700,700,12)
epsilons = np.linspace(-700, 700, 10)
T_L = 1
T_R = 1

INPUT = {
    'omega': 0.105,
    'u_intra': 150,
    'u_inter': 100,
    'gammaL': 0.1,
    'gammaR': 0.1,
    'T_L': T_L,
    'T_R': T_R,
}

# %%
importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
#Plotting data

Epsilon, VB = np.meshgrid(epsilons, VBs)

contour = plt.contourf(Epsilon, VB, I, 20, cmap='bone')
plt.colorbar(contour)
plt.xlabel('epsilon')
plt.ylabel('V_B')
plt.title('Current for different values of V_B and epsilon')
plt.show()

contour = plt.contourf(Epsilon, VB, P_0, 20, cmap='bone')
plt.colorbar(contour)
plt.xlabel('epsilon')
plt.ylabel('V_B')
plt.title('P_0 for different values of V_B and epsilon')
plt.show()

# %%
#TEST OF vb_sweeper

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-10000,10000, 100) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-6000, 6000, 10) # np.linspace(-6000, 6000, 10)
T_L = 100 #100
T_R = T_L #T_L

INPUT = {
    'omega': 0.5, #1000
    'u_intra': 2000, #2000
    'u_inter': 1000, #1000
    'gammaL': 0.5, #0.5
    'gammaR': 0.5, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

'''
I = np.zeros((len(V_B),len(epsilons)))

for e_idx, eps in enumerate(epsilons):
    for v_idx, vb in enumerate(V_B):
        system = qmeq.Builder(nsingle=n, hsingle={(0,0):eps, (1,1):eps, (2,2):eps, (3,3):eps, (0,2):omega, (1,3):omega}, coulomb=U, nleads=nleads,
                        mulst={0:-vb/2, 1:-vb/2, 2:vb/2, 3:vb/2}, tlst=tlst, tleads={(0, 0):tL, (1, 1):tL, (2, 2):tR, (3, 3):tR}, dband=1e4, countingleads=[0,1], kerntype='pyLindblad')

        system.solve()
        I[v_idx, e_idx] = system.current_noise[0]
        I[v_idx, e_idx] = system.current[0]+system.current[1]
'''

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
'''
eps_mesh, V_B_mesh = np.meshgrid(epsilons, VBs)

contour = plt.contourf(eps_mesh, V_B_mesh, I, 20, cmap='bone')
plt.colorbar(contour)
plt.xlabel('epsilon')
plt.ylabel('V_B')
plt.title('Current for different values of V_B and epsilon')
plt.show()

contour = plt.contourf(eps_mesh, V_B_mesh, P_0, 20, cmap='bone')
plt.colorbar(contour)
plt.xlabel('epsilon')
plt.ylabel('V_B')
plt.title('P_0 for different values of V_B and epsilon')
'''

plt.imshow(I, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')

# %%
#TEST OF vb_sweeper

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-3000,3000, 20) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-5000, 1000, 20) # np.linspace(-6000, 6000, 10)
T_L = 100 #100
T_R = T_L #T_L

INPUT = {
    'omega': 0.5, #1000
    'u_intra': 2000, #2000
    'u_inter': 1000, #1000
    'gammaL': 0.5, #0.5
    'gammaR': 0.5, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
plt.imshow(I, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')

# %%
#high resolution coloumb diamonds

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-3000,3000, 100) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-5000, 1000, 100) # np.linspace(-6000, 6000, 10)
T_L = 100 #100
T_R = T_L #T_L

INPUT = {
    'omega': 0.5, #1000
    'u_intra': 2000, #2000
    'u_inter': 1000, #1000
    'gammaL': 0.5, #0.5
    'gammaR': 0.5, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
plt.imshow(I, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')

img = plt.imshow(I/T, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
img.set_clim(-0.1, 0.1)  # Set color limits

# %%
#Zoomed in

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-500,500, 20) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-1200, -750, 20) # np.linspace(-6000, 6000, 10)
T_L = 100 #100
T_R = 65 #T_L

INPUT = {
    'omega': 0.5, #1000
    'u_intra': 2000, #2000
    'u_inter': 1000, #1000
    'gammaL': 0.5, #0.5
    'gammaR': 0.5, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
if T_L < T_R:
    raise SystemExit("Not my convention! (T_L < T_R)")
elif T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L
#elif T_L == T_R:

#Calculations of efficiency, sigma and TUR
eff_carnot = 1-(T_COLD/T_HOT)
eff = P/J_QH
P[(P < 0)] = np.nan
sigma = P*(1/T_COLD)*(eff_carnot-eff)/eff
TUR = I_var*sigma/(I**2)
print(TUR[~np.isnan(TUR)])
# Out:
# [2.01433186 2.07016372 2.04408292 2.02465857 2.01198566 2.00656939
#  2.0198656  2.19092749 2.0745227  2.06171921 2.07196808 2.09631478
#  2.13343372 2.18419286 2.25113564 6.86780732 3.38848169 2.9703539 ]

# %%
img = plt.imshow(TUR, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
img.set_clim(1.5, 2.5)  # Set color limits

# %%
#///////////////        ///////////////////////           ///////////////////           //////////////////////          ////////////////////////

# %%
#TEST OF vb_sweeper

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-300,300, 100) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-500, 100, 100) # np.linspace(-6000, 6000, 10)
T = 1
T_L = T #100
T_R = T #T_L

INPUT = {
    'omega': 0.1, #1000
    'u_intra': 200, #2000
    'u_inter': 100, #1000
    'gammaL': 0.1, #0.5
    'gammaR': 0.1, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)
# Out:
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -4.946668518309855e-16 for V_B: -81.81818181818181 and epsilon: -209.09090909090912
#  (I = -2.442866531635445e-16, J_QH = 4.643120541764652e-14)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -7.806222900659498e-14 for V_B: -75.75757575757575 and epsilon: -178.7878787878788
#  (I = -3.4742871748044825e-14, J_QH = 6.8203282984282624e-12)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1.923614629574915e-08 for V_B: -63.636363636363626 and epsilon: -172.72727272727275
#  (I = -1.2173526287206059e-08, J_QH = 2.7315662113374056e-06)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1.9292010158602415e-15 for V_B: -57.575757575757564 and epsilon: -190.90909090909093
#  (I = -2.930336664597144e-16, J_QH = 2.7326424135207087e-13)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -3516331312653633.0 for V_B: -51.51515151515153 and epsilon: -196.969696969697
#  (I = 3.2799648205465615, J_QH = -246.99134731284025)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -0.3913672629289698 for V_B: -51.51515151515153 and epsilon: -184.84848484848487
#  (I = -2.8362589932078956e-10, J_QH = 5.547712998040869e-08)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1.5970656869149817e-09 for V_B: -45.45454545454547 and epsilon: -184.84848484848487
#  (I = 1.783045559673083e-13, J_QH = -2.578682631799456e-11)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -0.0030874400630010223 for V_B: -45.45454545454547 and epsilon: -160.60606060606062
#  (I = 0.00018846967521314915, J_QH = -0.01778276114022618)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1.321041111703313 for V_B: -39.39393939393938 and epsilon: -166.66666666666669
#  (I = -0.02859308556471057, J_QH = 4.445100329041989)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1295257182.7431266 for V_B: -39.39393939393938 and epsilon: -160.60606060606062
#  (I = -42.35296684316022, J_QH = 7514.396415947518)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\../../temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise!
, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)
#
# File c:\../../temp_prog\vb_epsilon_sweeper.py:41, in run_sweep(VBs, epsilons, omega, u_intra, u_inter, gammaL, gammaR, T_L, T_R)
#      37 for e_idx, eps in enumerate(epsilons):
#      38     system = qmeq.Builder(nsingle=n, hsingle={(0,0):eps, (1,1):eps, (2,2):eps, (3,3):eps, (0,2):omega, (1,3):omega}, coulomb=U, nleads=nleads,
#      39                     mulst={0:mu_L, 1:mu_L, 2:mu_R, 3:mu_R}, tlst=tlst, tleads={(0, 0):tL, (1, 1):tL, (2, 2):tR, (3, 3):tR},
#      40                     dband=1e4, countingleads=[0,1], kerntype='pyLindblad')
# ---> 41     system.solve()
#      42     i = system.current_noise[0]
#      43     i_var = system.current_noise[1]
#
# File c:\../QmeQ/qmeq\qmeq\approach\aprclass.py:393, in Approach.solve(self, qdq, rotateq, masterq, currentq, *args, **kwargs)
#     391     self.solve_matrix_free()
#     392 if currentq:
# --> 393     self.generate_current()
#
# File c:\../QmeQ/qmeq\qmeq\approach\base\lindblad.py:128, in ApproachLindblad.generate_current(self)
#     126 def generate_current(self):
#     127     self.generate_current_std()
# --> 128     self.generate_current_noise()
#
# File c:\../QmeQ/qmeq\qmeq\approach\base\lindblad.py:205, in ApproachLindblad.generate_current_noise(self)
#     203 Q = (np.eye(np.size(P)) - P @ O)
#     204 # pseudoinverse
# --> 205 R   = Q @ np.linalg.pinv(kern) @ Q
#     207 # current and noise
#     208 Jp  = 1j*Lp - 1j*Lm
#
# File c:\temp_prog\venv\Lib\site-packages\numpy\linalg\_linalg.py:2231, in pinv(a, rcond, hermitian, rtol)
#    2229     return wrap(res)
#    2230 a = a.conjugate()
# -> 2231 u, s, vt = svd(a, full_matrices=False, hermitian=hermitian)
#    2233 # discard small singular values
#    2234 cutoff = rcond[..., newaxis] * amax(s, axis=-1, keepdims=True)
#
# File c:\temp_prog\venv\Lib\site-packages\numpy\linalg\_linalg.py:1812, in svd(a, full_matrices, compute_uv, hermitian)
#    1808 signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
#    1809 with errstate(call=_raise_linalgerror_svd_nonconvergence,
#    1810               invalid='call', over='ignore', divide='ignore',
#    1811               under='ignore'):
# -> 1812     u, s, vh = gufunc(a, signature=signature)
#    1813 u = u.astype(result_t, copy=False)
#    1814 s = s.astype(_realType(result_t), copy=False)
#
# File c:\temp_prog\venv\Lib\site-packages\numpy\linalg\_linalg.py:113, in _raise_linalgerror_svd_nonconvergence(err, flag)
#     112 def _raise_linalgerror_svd_nonconvergence(err, flag):
# --> 113     raise LinAlgError("SVD did not converge")
#
# LinAlgError: SVD did not converge

# %%
img = plt.imshow(I/T, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
img.set_clim(-0.1, 0.1)  # Set color limits
plt.show()

# %%
#SÖKA EFTER TUR VIOLATIONS IN SERIAL DOT EFTER SEGAL PAPER

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(0,0.2, 20) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-0.8, 0.8, 20) # np.linspace(-6000, 6000, 10)
#T = 1
T_L = 2.5 #100
T_R = 1 #T_L

INPUT = {
    'omega': 0.005, #1000
    'u_intra': 0, #2000
    'u_inter': 0, #1000
    'gammaL': 0.005, #0.5
    'gammaR': 0.005, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
if T_L < T_R:
    raise SystemExit("Not my convention! (T_L < T_R)")
elif T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L
#elif T_L == T_R:

#Calculations of efficiency, sigma and TUR
eff_carnot = 1-(T_COLD/T_HOT)
eff = P/J_QH
P[(P < 0)] = np.nan
sigma = P*(1/T_COLD)*(eff_carnot-eff)/eff
TUR = I_var*sigma/(I**2)
print(np.sort(TUR[~np.isnan(TUR)]))
# Out:
#
# np.linspace(-10000,10000, 100)
epsilons = np.linspace(-9, 9, 100) # np.linspace(-6000, 6000, 10)
#T = 1
T_L = 2.5 #100
T_R = 1 #T_L

INPUT = {
    'omega': 0.002, #1000
    'u_intra': 1000, #2000
    'u_inter': 800, #1000
    'gammaL': 0.005, #0.5
    'gammaR': 0.005, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
if T_L < T_R:
    raise SystemExit("Not my convention! (T_L < T_R)")
elif T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L
#elif T_L == T_R:

#Calculations of efficiency, sigma and TUR
eff_carnot = 1-(T_COLD/T_HOT)
eff = P/J_QH
P[(P < 0)] = np.nan
sigma = P*(1/T_COLD)*(eff_carnot-eff)/eff
TUR = I_var*sigma/(I**2)
print(np.sort(TUR[~np.isnan(TUR)]))
# Out:
# [1.96941951 1.96968589 1.97197786 ... 5.06642308 5.11460074 5.16276608]
# C:\Users\ag3830he\AppData\Local\Temp\ipykernel_6228\3275617505.py:12: RuntimeWarning: invalid value encountered in divide
#   sigma = P*(1/T_COLD)*(eff_carnot-eff)/eff

# %%
Epsilon, VB = np.meshgrid(epsilons, VBs)

# %%
unique_sorted_values = np.unique(TUR)

# Ensure there are at least 20 unique values
if len(unique_sorted_values) >= 20:
    target_value = unique_sorted_values[19]  # 20th smallest value
    
    # Get indices of all values up to and including the 20th smallest
    indices = np.argwhere(TUR <= target_value)
    #print("Indices of the 20th smallest and all smaller values:\n", indices)
else:
    print("Not enough unique values in the array!")

print("shape TUR",TUR.shape)
print("shape indices",indices.shape)

for row in indices:
    print("TUR: ",TUR[row[0],row[1]])
    print("Epsilon", Epsilon[row[0], row[1]])
    print("VB", VB[row[0],row[1]])
#print(TUR[indices[0,0]][indices[0,1]])

vio_row = indices[3,0]
vio_col =  indices[3,1]
#print(TUR[indices[3,0],indices[3,1]])
#print(vio_row)
#print(vio_col)
# Out:
# shape TUR (100, 100)
# shape indices (20, 2)
# TUR:  1.9771255711071867
# Epsilon 1.1818181818181817
# VB 0.08080808080808081
# TUR:  1.9725245053127896
# Epsilon 1.3636363636363633
# VB 0.08080808080808081
# TUR:  1.9696858944653488
# Epsilon 1.545454545454545
# VB 0.08080808080808081
# TUR:  1.9694195081129258
# Epsilon 1.7272727272727284
# VB 0.08080808080808081
# TUR:  1.9724678531363764
# Epsilon 1.90909090909091
# VB 0.08080808080808081
# TUR:  1.9794817753435354
# Epsilon 2.0909090909090917
# VB 0.08080808080808081
# TUR:  1.9759983667341718
# Epsilon 1.3636363636363633
# VB 0.16161616161616163
# TUR:  1.9728396066432659
# Epsilon 1.545454545454545
# VB 0.16161616161616163
# TUR:  1.9719778591501134
# Epsilon 1.7272727272727284
# VB 0.16161616161616163
# TUR:  1.97417398134949
# Epsilon 1.90909090909091
# VB 0.16161616161616163
# TUR:  1.9801051585564604
# Epsilon 2.0909090909090917
# VB 0.16161616161616163
# TUR:  1.979320821623389
# Epsilon 1.3636363636363633
# VB 0.24242424242424243
# TUR:  1.9759229606805269
# Epsilon 1.545454545454545
# VB 0.24242424242424243
# TUR:  1.9745444266484435
# Epsilon 1.7272727272727284
# VB 0.24242424242424243
# TUR:  1.9759609036956693
# Epsilon 1.90909090909091
# VB 0.24242424242424243
# TUR:  1.9789142251301517
# Epsilon 1.545454545454545
# VB 0.32323232323232326
# TUR:  1.9770989829397758
# Epsilon 1.7272727272727284
# VB 0.32323232323232326
# TUR:  1.9778108659998095
# Epsilon 1.90909090909091
# VB 0.32323232323232326
# TUR:  1.9796209420411095
# Epsilon 1.7272727272727284
# VB 0.4040404040404041
# TUR:  1.979705489430648
# Epsilon 1.90909090909091
# VB 0.4040404040404041

# %%
print("Epsilon:",Epsilon[vio_row, vio_col])
print("VB:",VB[vio_row, vio_col])
# Out:
# Epsilon: 1.7272727272727284
# VB: 0.08080808080808081

# %%
#BEKRÄFTA LÄGSTA TUR:

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(VB[vio_row, vio_col],VB[vio_row, vio_col], 1) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(Epsilon[vio_row, vio_col], Epsilon[vio_row, vio_col], 1) # np.linspace(-6000, 6000, 10)
#T = 1
T_L = 2.5 #100
T_R = 1 #T_L

INPUT = {
    'omega': 0.002, #1000
    'u_intra': 1000, #2000
    'u_inter': 800, #1000
    'gammaL': 0.005, #0.5
    'gammaR': 0.005, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I_vio, I_var_vio, J_QH_vio, P_vio, P_0_vio = vs.run_sweep(VBs, epsilons, **INPUT)

print(I_vio)
print(P_vio)
# Out:
# [[0.00026338]]
# [[2.12830435e-05]]

# %%
if T_L < T_R:
    raise SystemExit("Not my convention! (T_L < T_R)")
elif T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L
#elif T_L == T_R:

print(T_L, T_R)

#Calculations of efficiency, sigma and TUR
eff_carnot = 1-(T_COLD/T_HOT)
eff_vio = P_vio/J_QH_vio
print(eff_vio)
P_vio[(P_vio < 0)] = np.nan
sigma_vio = P_vio*(1/T_COLD)*(eff_carnot-eff_vio)/eff_vio
TUR_vio = I_var_vio*sigma_vio/(I_vio**2)
print(np.sort(TUR_vio[~np.isnan(TUR_vio)]))
# Out:
# 2.5 1
# [[0.04571427]]
# [1.96941951]

# %%
img = plt.imshow(I, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
plt.xlabel('epsilon')
plt.ylabel('V')
#img.set_clim(-0.1, 0.1)  # Set color limits
plt.show()

TUR_masked = np.ma.masked_where(TUR >= 1.98, TUR)

img = plt.imshow(TUR_masked, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
plt.xlabel('epsilon')
plt.ylabel('V')
#for row in indices:
#    plt.scatter(Epsilon[row[0], row[1]],VB[row[0],row[1]],marker="o")
#img.set_clim(-0.1, 0.1)  # Set color limits
# Out:
# Text(0, 0.5, 'V')

# %%
#ZOOMAR IN PÅ INTRESSANT OMRÅDE:


#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(0,0.5, 20) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(0, 2.1, 20) # np.linspace(-6000, 6000, 10)
#T = 1
T_L = 2.5 #100
T_R = 1 #T_L

INPUT = {
    'omega': 0.002, #1000
    'u_intra': 1000, #2000
    'u_inter': 800, #1000
    'gammaL': 0.005, #0.5
    'gammaR': 0.005, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
if T_L < T_R:
    raise SystemExit("Not my convention! (T_L < T_R)")
elif T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L
#elif T_L == T_R:

#Calculations of efficiency, sigma and TUR
eff_carnot = 1-(T_COLD/T_HOT)
eff = P/J_QH
P[(P < 0)] = np.nan
sigma = P*(1/T_COLD)*(eff_carnot-eff)/eff
TUR = I_var*sigma/(I**2)
print(np.sort(TUR[~np.isnan(TUR)]))
# Out:
# [1.96733343 1.96737743 1.96826113 1.96826175 1.96834284 1.96853587
#  1.96914667 1.96926589 1.9693494  1.96936752 1.9700022  1.97001116
#  1.97003335 1.97035239 1.9704656  1.97074416 1.9709205  1.97094037
#  1.97118296 1.97135106 1.9714904  1.97149113 1.97155522 1.97180739
#  1.97205088 1.97224244 1.97234211 1.97234469 1.97242322 1.97262123
#  1.97263562 1.97269333 1.97299744 1.97320087 1.97333253 1.97348785
#  1.9735776  1.97363015 1.97370604 1.97375547 1.9737892  1.97431385
#  1.9743856  1.9744595  1.97451584 1.97461939 1.97471105 1.97476571
#  1.97481949 1.97498948 1.97505661 1.97527789 1.97528788 1.97533469
#  1.97533831 1.97541648 1.97560021 1.97573597 1.97579013 1.97581389
#  1.97599046 1.97604093 1.97617703 1.97621329 1.97621716 1.9762539
#  1.97654586 1.97657666 1.97680428 1.97683683 1.97683969 1.97684981
#  1.97698846 1.97708374 1.9771423  1.97721115 1.97741189 1.97746718
#  1.97756724 1.9777346  1.9778464  1.9778727  1.9779212  1.97794892
#  1.97809897 1.97815889 1.97827426 1.9782914  1.97832911 1.97858053
igma = P*(1/T_COLD)*(eff_carnot-eff)/eff

# %%
img = plt.imshow(I, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
plt.xlabel('epsilon')
plt.ylabel('V')
#img.set_clim(-0.1, 0.1)  # Set color limits
plt.show()

TUR_masked = np.ma.masked_where(TUR >= 1.98, TUR)

img = plt.imshow(TUR_masked, extent=[epsilons[0], epsilons[-1], VBs[0], VBs[-1]], aspect='auto', origin='lower')
plt.colorbar()
plt.xlabel('epsilon')
plt.ylabel('V')
#for row in indices:
#    plt.scatter(Epsilon[row[0], row[1]],VB[row[0],row[1]],marker="o")
#img.set_clim(-0.1, 0.1)  # Set color limits
# Out:
# Text(0, 0.5, 'V')

# %%
print(np.nanmin(TUR))

min_idx = np.argwhere(TUR == np.nanmin(TUR))

print(min_idx)

print(TUR[1,15])

Epsilon, VB = np.meshgrid(epsilons, VBs)
print("Epsilon:", Epsilon[1,15])
print("VB:", VB[1,15])
# Out:
# 1.9673334325717584
# [[ 1 15]]
# 1.9673334325717584
# Epsilon: 1.6578947368421053
# VB: 0.02631578947368421

# %%
#////////////////////////////////////SÖKA EFTER TUR VIOLATIONS IN SERIAL DOT EFTER ENTANGLEMENT PAPER////////////////////////////////////////////////

#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-500,500, 20) # np.linspace(-10000,10000, 100)
epsilons = np.linspace(-800, 800, 20) # np.linspace(-6000, 6000, 10)
#T = 100
T_L = 150 #100
T_R = 100 #T_L

INPUT = {
    'omega': 0.4, #1000
    'u_intra': 1000, #2000
    'u_inter': 700, #1000
    'gammaL': 1, #0.5
    'gammaR': 1, #0.5
    'T_L': T_L,
    'T_R': T_R,
}

#--SETUP: ---------------------------------------------------------------------------------

importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)

# %%
if T_L < T_R:
    raise SystemExit("Not my convention! (T_L < T_R)")
elif T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L
#elif T_L == T_R:

#Calculations of efficiency, sigma and TUR
eff_carnot = 1-(T_COLD/T_HOT)
eff = P/J_QH
P[(P < 0)] = np.nan
sigma = P*(1/T_COLD)*(eff_carnot-eff)/eff
TUR = I_var*sigma/(I**2)
print(np.sort(TUR[~np.isnan(TUR)]))
# Out:
# [2.01595629e+00 2.03133497e+00 2.04274816e+00 2.05111830e+00
#  2.05470659e+00 2.06437267e+00 2.06869055e+00 2.07788025e+00
#  2.07886371e+00 2.08240141e+00 2.10802643e+00 2.11645107e+00
#  2.11990185e+00 2.15799992e+00 2.15836461e+00 2.18416216e+00
#  2.19807261e+00 2.20588165e+00 2.22581469e+00 2.26158410e+00
#  2.31730648e+00 2.34844383e+00 2.36424609e+00 2.38852873e+00
#  2.45924758e+00 2.52486902e+00 2.62036368e+00 2.70244664e+00
#  2.89423405e+00 3.63146241e+00 8.97159150e+00 9.32795261e+00
#  1.82319267e+01 1.93667409e+01 3.06130673e+01 6.09351092e+01
#  4.82326576e+02 4.09579571e+03]
