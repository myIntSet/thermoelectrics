# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import importlib

import vb_epsilon_sweeper as vs
import file_handler as fh
# Out:
# WARNING: Cannot import Cython compiled modules for the special functions (specfunc.__init__.py).
# WARNING: Cannot import Cython compiled modules for the approaches (builder_base.py).
# WARNING: Cannot import Cython compiled modules for the approaches (builder_elph.py).

# %%
#--SETUP: ---------------------------------------------------------------------------------
VBs = np.linspace(-200,200,12)
epsilons = np.linspace(-200, 200, 10)
T_L = 1
T_R = 1

if T_L > T_R:
    T_COLD = T_R
    T_HOT = T_L

INPUT = {
    'omega': 0.105,
    'u_intra': 300,
    'u_inter': 200,
    'gammaL': 0.1,
    'gammaR': 0.105,
    'T_L': T_L,
    'T_R': T_R,
}

# %%
importlib.reload(vs)
I, I_var, J_QH, P, P_0 = vs.run_sweep(VBs, epsilons, **INPUT)
# Out:
# c:\temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1.7770046101859914e-16 for V_B: -90.9090909090909 and epsilon: -111.11111111111111
#  (I = -1.7763344627049018e-16, J_QH = 2.7811754062480785e-14)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -1.7770269953287825e-16 for V_B: -18.18181818181816 and epsilon: -66.66666666666669
#  (I = -1.7763568394002498e-16, J_QH = 1.3457248783335227e-14)
#   warnings.warn(f"Warning! Negative noise! {i_var} for V_B: {vb} and epsilon: {eps}\n (I = {i}, J_QH = {j_qh})")
# c:\temp_prog\vb_epsilon_sweeper.py:46: UserWarning: Warning! Negative noise! -7.112803765077566e-16 for V_B: 18.181818181818187 and epsilon: -111.11111111111111
#  (I = -7.105427357600999e-16, J_QH = 7.248971344623242e-14)
# ...

# %%
#Plotting data

Epsilon, VB = np.meshgrid(epsilons, VBs)

contour = plt.contourf(Epsilon, VB, I, 20, cmap='bone')
plt.colorbar(contour)
plt.xlabel('epsilon')
plt.ylabel('V_B')
plt.title('Current for different values of V_B and epsilon')
plt.show()
